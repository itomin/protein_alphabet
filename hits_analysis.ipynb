# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("C:/Users/tomin/dev/data/cath_hits_annotated.csv", escapechar="\\", header=None,
                names=["hit", "cath", "c", "a", "t", "h", "N"])

# %%
df.shape
# Out:
# (10210361, 7)

# %% [markdown]
# ##### Length distribution of pairwise matches

# %%
hits = df[["hit", "N"]].drop_duplicates()

# %%
hits.N.hist(bins=50, figsize=(20,10))

# %%
plt.figure(figsize=(20,10))
plt.plot(hits.N.quantile(np.linspace(0,1,70)))

# %% [markdown]
# Class
# * 1 =  Mainly Alpha
# * 2 =  Mainly Beta
# * 3 =  Alpha Beta
# * 4 = Few Secondary Structures

# %%
hitsClass = df[["hit", "c", "N"]].drop_duplicates()

# %%
hitsClass.head()ö
# Out:
#       hit  c  N
# 0  ²²√√²²  3  6
# 1  ²²√√²²  1  6
# 2   √²≈√∞  3  5
# 6     ;Xσ  1  3
# 7     ;Xσ  2  3

# %%
commonHits = hitsClass.groupby(["hit", "N"]).size().reset_index(name="Nclass")

# %%
commonHits[(commonHits.Nclass == 3) & (commonHits.N > 20) ]
# Out:
#                                        hit   N  Nclass
# 40748                ,,,,,,,,,,,,,,,,,,,,,  21       3
# 40749               ,,,,,,,,,,,,,,,,,,,,,,  22       3
# 40750              ,,,,,,,,,,,,,,,,,,,,,,,  23       3
# 40751             ,,,,,,,,,,,,,,,,,,,,,,,,  24       3
# 40752            ,,,,,,,,,,,,,,,,,,,,,,,,,  25       3
# 40753           ,,,,,,,,,,,,,,,,,,,,,,,,,,  26       3
# 40754          ,,,,,,,,,,,,,,,,,,,,,,,,,,,  27       3
# 40755         ,,,,,,,,,,,,,,,,,,,,,,,,,,,,  28       3
# 40756        ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,  29       3
# 40757       ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,  30       3
# 40758      ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,  31       3
# 40759     ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,  32       3
# 40760    ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,  33       3
# 40761   ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,  34       3
# 40762  ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,  35       3

# %%
commonHits
# Out:
#           hit  N  Nclass
# 0           !  1       4
# 1          !!  2       4
# 2         !!!  3       4
# 3        !!!!  4       4
# 4       !!!!/  5       1
# 5        !!!$  4       3
# 6        !!!%  4       1
# 7        !!!'  4       4
# 8        !!!)  4       2
# 9        !!!,  4       3
# 10       !!!/  4       1
# 11       !!!1  4       2
# 12       !!!3  4       2
# 13       !!!4  4       2
# 14       !!!5  4       3
# 15       !!!7  4       3
# 16       !!!?  4       1
# 17       !!!T  4       2
# 18       !!!V  4       1
# 19       !!!q  4       1
# 20        !!"  3       2
# 21        !!#  3       3
# 22        !!$  3       4
# 23       !!$!  4       2
# 24       !!$+  4       2
# 25       !!$,  4       3
# 26       !!$1  4       2
# 27       !!$3  4       1
# 28        !!%  3       3
# 29       !!%4  4       1
# ...       ... ..     ...
# 681043   ■■≈≈  4       2
# 681044    ■■≡  3       2
# 681045    ■■≤  3       1
# 681046    ■■≥  3       2
# 681047   ■■≥≈  4       2
# ...
