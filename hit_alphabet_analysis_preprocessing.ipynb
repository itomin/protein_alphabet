# %%
import pandas as pd
from os import listdir
import numpy as np
from os.path import isfile, join
from Bio import SeqIO
import re
import seaborn as sns

HOME_DIR = "../data/pdb_str/"
PB_HITS_DIR = "../data/pdb_str/pb_hits/"
MK_HITS_DIR = "../data/pdb_str/m32k25_hits/"
AA_HITS_DIR = "../data/pdb_str/aa_hits/"
CHEM_HITS_DIR = "../data/pdb_str/chem_hits/"
CS219_HITS_DIR = "../data/pdb_str/cs219_hits/"

# %%
clearEmpty = lambda x: [ i for i in x if i != '']
regex = re.compile('[^0-9]')

aa_filter = pd.read_csv("aa_hits_sample.csv")
aa_filter = aa_filter[aa_filter.hit_length >= 10]
aa_filter["key"] = aa_filter[["x", "y"]].apply(lambda x: "%s_%s" % (x.x, x.y), axis=1)
aa_filter["key_revert"] = aa_filter[["x", "y"]].apply(lambda x: "%s_%s" % (x.y, x.x), axis=1)
aa_filter.shape

def parse_interval(range):
    segs = [ seg.split("-")  for seg in range.split(",")]
    segs = [ clearEmpty(s) for s in segs ]
    return [ [ int(regex.sub('', s[0])), int(regex.sub('', s[1]).split(":")[0]) ] for s in segs]

def merge_range(elem):
    return ",".join([ ":".join( [str(o) for o in pair] ) for pair in elem])

def readPDB(path):
    for record in SeqIO.parse(path, "fasta"):
        pdb = "".join(list(record.seq))
    return pdb

def filterByAA(df):
    df["key"] = df[["x", "y"]].apply(lambda x: "%s_%s" % (x.x, x.y), axis=1)
    df = pd.merge(df, aa_filter[["key", "key_revert"]], on="key", how="left")
    df = pd.merge(df, aa_filter[["key", "key_revert"]], left_on="key", right_on="key_revert", how="left")
    df = df[df.key_revert_x.isna() & df.key_revert_y.isna()]
    return df

def filterEqChain(df):
    df["chain_x"] = df.x.apply(lambda r: r[0:-3])
    df["chain_y"] = df.y.apply(lambda r: r[0:-3])
    df = df[df.chain_x != df.chain_y]
    df = df.drop(columns=["chain_x", "chain_y"])
    return df
    

def countFileBy(i, F, key):
    print(i, F)
    _df = pd.read_csv(F)
    print("filter by AA")
    _df = filterByAA(_df)
    print("filter eq Chain")
    _df = filterEqChain(_df)
    _counts = _df.groupby(key).size().reset_index(name="N")
    _counts.to_csv("../data/pdb_str/statistics/temp/%s.csv" % F.split("/")[-1], index=False)
    return _counts

# %%
def histogram_hit_length(source, target):
    files = [ "".join([source, f]) for f in listdir(source) ]
#     files = files[657:-1]
    counts = [ countFileBy(f, files[f], "hit") for f in range(len(files))]
    df = pd.concat(counts)
    df = df.groupby("hit").N.sum().reset_index(name="N")
    df.to_csv("../data/pdb_str/statistics/%s" % target, index=False)

# %%
# histogram_hit_length(PB_HITS_DIR, "pb_histogram_count_by_hit.csv")
histogram_hit_length(MK_HITS_DIR, "m32k25_histogram_count_by_hit.csv")
# histogram_hit_length(AA_HITS_DIR, "aa_histogram_count_by_hit.csv")
# histogram_hit_length(CHEM_HITS_DIR, "chem_histogram_count_by_hit.csv")
# histogram_hit_length(CS219_HITS_DIR, "cs219_histogram_count_by_hit.csv")
# Out:
# 0 ../data/pdb_str/cs219_hits/hits_xaz_cath_pairs_ah.gz
# filter by AA
# filter eq Chain
# 1 ../data/pdb_str/cs219_hits/hits_xaz_cath_pairs_ai.gz
# filter by AA
# filter eq Chain
# 2 ../data/pdb_str/cs219_hits/hits_xaz_cath_pairs_aj.gz
# filter by AA
# filter eq Chain
# 3 ../data/pdb_str/cs219_hits/hits_xaz_cath_pairs_ak.gz
# filter by AA
# filter eq Chain
# 4 ../data/pdb_str/cs219_hits/hits_xaz_cath_pairs_al.gz
# filter by AA
# filter eq Chain
# 5 ../data/pdb_str/cs219_hits/hits_xaz_cath_pairs_am.gz
# filter by AA
# filter eq Chain
# 6 ../data/pdb_str/cs219_hits/hits_xaz_cath_pairs_an.gz
# filter by AA
# filter eq Chain
# 7 ../data/pdb_str/cs219_hits/hits_xaz_cath_pairs_ao.gz
# filter by AA
# filter eq Chain
# 8 ../data/pdb_str/cs219_hits/hits_xaz_cath_pairs_ap.gz
# filter by AA
# filter eq Chain
# 9 ../data/pdb_str/cs219_hits/hits_xaz_cath_pairs_aq.gz
# filter by AA
# filter eq Chain
# 10 ../data/pdb_str/cs219_hits/hits_xaz_cath_pairs_ar.gz
# filter by AA
# filter eq Chain
# 11 ../data/pdb_str/cs219_hits/hits_xaz_cath_pairs_as.gz
# filter by AA
# filter eq Chain
# 12 ../data/pdb_str/cs219_hits/hits_xaz_cath_pairs_at.gz
# filter by AA
# filter eq Chain
# 13 ../data/pdb_str/cs219_hits/hits_xaz_cath_pairs_au.gz
# filter by AA
# filter eq Chain
# 14 ../data/pdb_str/cs219_hits/hits_xaz_cath_pairs_av.gz
# filter by AA
# filter eq Chain
# 15 ../data/pdb_str/cs219_hits/hits_xaz_cath_pairs_aw.gz
# filter by AA
# filter eq Chain
# 16 ../data/pdb_str/cs219_hits/hits_xaz_cath_pairs_ax.gz
# filter by AA
# filter eq Chain
# 17 ../data/pdb_str/cs219_hits/hits_xaz_cath_pairs_ay.gz
# filter by AA
# filter eq Chain
# 18 ../data/pdb_str/cs219_hits/hits_xaz_cath_pairs_az.gz
# filter by AA
# filter eq Chain
# 19 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_aa.gz
# filter by AA
# filter eq Chain
# 20 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_ab.gz
# filter by AA
# filter eq Chain
# 21 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_ac.gz
# filter by AA
# filter eq Chain
# 22 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_ad.gz
# filter by AA
# filter eq Chain
# 23 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_ae.gz
# filter by AA
# filter eq Chain
# 24 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_af.gz
# filter by AA
# filter eq Chain
# 25 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_ag.gz
# filter by AA
# filter eq Chain
# 26 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_ah.gz
# filter by AA
# filter eq Chain
# 27 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_ai.gz
# filter by AA
# filter eq Chain
# 28 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_aj.gz
# filter by AA
# filter eq Chain
# 29 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_ak.gz
# filter by AA
# filter eq Chain
# 30 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_al.gz
# filter by AA
# filter eq Chain
# 31 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_am.gz
# filter by AA
# filter eq Chain
# 32 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_an.gz
# filter by AA
# filter eq Chain
# 33 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_ao.gz
# filter by AA
# filter eq Chain
# 34 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_ap.gz
# filter by AA
# filter eq Chain
# 35 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_aq.gz
# filter by AA
# filter eq Chain
# 36 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_ar.gz
# filter by AA
# filter eq Chain
# 37 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_as.gz
# filter by AA
# filter eq Chain
# 38 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_at.gz
# filter by AA
# filter eq Chain
# 39 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_au.gz
# filter by AA
# filter eq Chain
# 40 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_av.gz
# filter by AA
# filter eq Chain
# 41 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_aw.gz
# filter by AA
# filter eq Chain
# 42 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_ax.gz
# filter by AA
# filter eq Chain
# 43 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_ay.gz
# filter by AA
# filter eq Chain
# 44 ../data/pdb_str/cs219_hits/hits_xba_cath_pairs_az.gz
# filter by AA
# filter eq Chain
# 45 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_aa.gz
# filter by AA
# filter eq Chain
# 46 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_ab.gz
# filter by AA
# filter eq Chain
# 47 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_ac.gz
# filter by AA
# filter eq Chain
# 48 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_ad.gz
# filter by AA
# filter eq Chain
# 49 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_ae.gz
# filter by AA
# filter eq Chain
# 50 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_af.gz
# filter by AA
# filter eq Chain
# 51 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_ag.gz
# filter by AA
# filter eq Chain
# 52 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_ah.gz
# filter by AA
# filter eq Chain
# 53 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_ai.gz
# filter by AA
# filter eq Chain
# 54 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_aj.gz
# filter by AA
# filter eq Chain
# 55 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_ak.gz
# filter by AA
# filter eq Chain
# 56 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_al.gz
# filter by AA
# filter eq Chain
# 57 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_am.gz
# filter by AA
# filter eq Chain
# 58 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_an.gz
# filter by AA
# filter eq Chain
# 59 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_ao.gz
# filter by AA
# filter eq Chain
# 60 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_ap.gz
# filter by AA
# filter eq Chain
# 61 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_aq.gz
# filter by AA
# filter eq Chain
# 62 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_ar.gz
# filter by AA
# filter eq Chain
# 63 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_as.gz
# filter by AA
# filter eq Chain
# 64 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_at.gz
# filter by AA
# filter eq Chain
# 65 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_au.gz
# filter by AA
# filter eq Chain
# 66 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_av.gz
# filter by AA
# filter eq Chain
# 67 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_aw.gz
# filter by AA
# filter eq Chain
# 68 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_ax.gz
# filter by AA
# filter eq Chain
# 69 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_ay.gz
# filter by AA
# filter eq Chain
# 70 ../data/pdb_str/cs219_hits/hits_xbb_cath_pairs_az.gz
# filter by AA
# filter eq Chain
# 71 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_aa.gz
# filter by AA
# filter eq Chain
# 72 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_ab.gz
# filter by AA
# filter eq Chain
# 73 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_ac.gz
# filter by AA
# filter eq Chain
# 74 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_ad.gz
# filter by AA
# filter eq Chain
# 75 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_ae.gz
# filter by AA
# filter eq Chain
# 76 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_af.gz
# filter by AA
# filter eq Chain
# 77 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_ag.gz
# filter by AA
# filter eq Chain
# 78 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_ah.gz
# filter by AA
# filter eq Chain
# 79 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_ai.gz
# filter by AA
# filter eq Chain
# 80 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_aj.gz
# filter by AA
# filter eq Chain
# 81 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_ak.gz
# filter by AA
# filter eq Chain
# 82 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_al.gz
# filter by AA
# filter eq Chain
# 83 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_am.gz
# filter by AA
# filter eq Chain
# 84 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_an.gz
# filter by AA
# filter eq Chain
# 85 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_ao.gz
# filter by AA
# filter eq Chain
# 86 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_ap.gz
# filter by AA
# filter eq Chain
# 87 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_aq.gz
# filter by AA
# filter eq Chain
# 88 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_ar.gz
# filter by AA
# filter eq Chain
# 89 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_as.gz
# filter by AA
# filter eq Chain
# 90 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_at.gz
# filter by AA
# filter eq Chain
# 91 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_au.gz
# filter by AA
# filter eq Chain
# 92 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_av.gz
# filter by AA
# filter eq Chain
# 93 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_aw.gz
# filter by AA
# filter eq Chain
# 94 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_ax.gz
# filter by AA
# filter eq Chain
# 95 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_ay.gz
# filter by AA
# filter eq Chain
# 96 ../data/pdb_str/cs219_hits/hits_xbc_cath_pairs_az.gz
# filter by AA
# filter eq Chain
# 97 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_aa.gz
# filter by AA
# filter eq Chain
# 98 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_ab.gz
# filter by AA
# filter eq Chain
# 99 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_ac.gz
# filter by AA
# filter eq Chain
# 100 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_ad.gz
# filter by AA
# filter eq Chain
# 101 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_ae.gz
# filter by AA
# filter eq Chain
# 102 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_af.gz
# filter by AA
# filter eq Chain
# 103 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_ag.gz
# filter by AA
# filter eq Chain
# 104 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_ah.gz
# filter by AA
# filter eq Chain
# 105 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_ai.gz
# filter by AA
# filter eq Chain
# 106 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_aj.gz
# filter by AA
# filter eq Chain
# 107 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_ak.gz
# filter by AA
# filter eq Chain
# 108 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_al.gz
# filter by AA
# filter eq Chain
# 109 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_am.gz
# filter by AA
# filter eq Chain
# 110 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_an.gz
# filter by AA
# filter eq Chain
# 111 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_ao.gz
# filter by AA
# filter eq Chain
# 112 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_ap.gz
# filter by AA
# filter eq Chain
# 113 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_aq.gz
# filter by AA
# filter eq Chain
# 114 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_ar.gz
# filter by AA
# filter eq Chain
# 115 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_as.gz
# filter by AA
# filter eq Chain
# 116 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_at.gz
# filter by AA
# filter eq Chain
# 117 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_au.gz
# filter by AA
# filter eq Chain
# 118 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_av.gz
# filter by AA
# filter eq Chain
# 119 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_aw.gz
# filter by AA
# filter eq Chain
# 120 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_ax.gz
# filter by AA
# filter eq Chain
# 121 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_ay.gz
# filter by AA
# filter eq Chain
# 122 ../data/pdb_str/cs219_hits/hits_xbd_cath_pairs_az.gz
# filter by AA
# filter eq Chain
# 123 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_aa.gz
# filter by AA
# filter eq Chain
# 124 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_ab.gz
# filter by AA
# filter eq Chain
# 125 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_ac.gz
# filter by AA
# filter eq Chain
# 126 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_ad.gz
# filter by AA
# filter eq Chain
# 127 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_ae.gz
# filter by AA
# filter eq Chain
# 128 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_af.gz
# filter by AA
# filter eq Chain
# 129 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_ag.gz
# filter by AA
# filter eq Chain
# 130 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_ah.gz
# filter by AA
# filter eq Chain
# 131 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_ai.gz
# filter by AA
# filter eq Chain
# 132 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_aj.gz
# filter by AA
# filter eq Chain
# 133 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_ak.gz
# filter by AA
# filter eq Chain
# 134 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_al.gz
# filter by AA
# filter eq Chain
# 135 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_am.gz
# filter by AA
# filter eq Chain
# 136 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_an.gz
# filter by AA
# filter eq Chain
# 137 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_ao.gz
# filter by AA
# filter eq Chain
# 138 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_ap.gz
# filter by AA
# filter eq Chain
# 139 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_aq.gz
# filter by AA
# filter eq Chain
# 140 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_ar.gz
# filter by AA
# filter eq Chain
# 141 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_as.gz
# filter by AA
# filter eq Chain
# 142 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_at.gz
# filter by AA
# filter eq Chain
# 143 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_au.gz
# filter by AA
# filter eq Chain
# 144 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_av.gz
# filter by AA
# filter eq Chain
# 145 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_aw.gz
# filter by AA
# filter eq Chain
# 146 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_ax.gz
# filter by AA
# filter eq Chain
# 147 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_ay.gz
# filter by AA
# filter eq Chain
# 148 ../data/pdb_str/cs219_hits/hits_xbe_cath_pairs_az.gz
# filter by AA
# filter eq Chain
# 149 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_aa.gz
# filter by AA
# filter eq Chain
# 150 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_ab.gz
# filter by AA
# filter eq Chain
# 151 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_ac.gz
# filter by AA
# filter eq Chain
# 152 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_ad.gz
# filter by AA
# filter eq Chain
# 153 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_ae.gz
# filter by AA
# filter eq Chain
# 154 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_af.gz
# filter by AA
# filter eq Chain
# 155 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_ag.gz
# filter by AA
# filter eq Chain
# 156 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_ah.gz
# filter by AA
# filter eq Chain
# 157 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_ai.gz
# filter by AA
# filter eq Chain
# 158 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_aj.gz
# filter by AA
# filter eq Chain
# 159 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_ak.gz
# filter by AA
# filter eq Chain
# 160 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_al.gz
# filter by AA
# filter eq Chain
# 161 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_am.gz
# filter by AA
# filter eq Chain
# 162 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_an.gz
# filter by AA
# filter eq Chain
# 163 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_ao.gz
# filter by AA
# filter eq Chain
# 164 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_ap.gz
# filter by AA
# filter eq Chain
# 165 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_aq.gz
# filter by AA
# filter eq Chain
# 166 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_ar.gz
# filter by AA
# filter eq Chain
# 167 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_as.gz
# filter by AA
# filter eq Chain
# 168 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_at.gz
# filter by AA
# filter eq Chain
# 169 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_au.gz
# filter by AA
# filter eq Chain
# 170 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_av.gz
# filter by AA
# filter eq Chain
# 171 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_aw.gz
# filter by AA
# filter eq Chain
# 172 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_ax.gz
# filter by AA
# filter eq Chain
# 173 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_ay.gz
# filter by AA
# filter eq Chain
# 174 ../data/pdb_str/cs219_hits/hits_xbf_cath_pairs_az.gz
# filter by AA
# filter eq Chain
# 175 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_aa.gz
# filter by AA
# filter eq Chain
# 176 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_ab.gz
# filter by AA
# filter eq Chain
# 177 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_ac.gz
# filter by AA
# filter eq Chain
# 178 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_ad.gz
# filter by AA
# filter eq Chain
# 179 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_ae.gz
# filter by AA
# filter eq Chain
# 180 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_af.gz
# filter by AA
# filter eq Chain
# 181 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_ag.gz
# filter by AA
# filter eq Chain
# 182 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_ah.gz
# filter by AA
# filter eq Chain
# 183 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_ai.gz
# filter by AA
# filter eq Chain
# 184 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_aj.gz
# filter by AA
# filter eq Chain
# 185 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_ak.gz
# filter by AA
# filter eq Chain
# 186 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_al.gz
# filter by AA
# filter eq Chain
# 187 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_am.gz
# filter by AA
# filter eq Chain
# 188 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_an.gz
# filter by AA
# filter eq Chain
# 189 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_ao.gz
# filter by AA
# filter eq Chain
# 190 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_ap.gz
# filter by AA
# filter eq Chain
# 191 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_aq.gz
# filter by AA
# filter eq Chain
# 192 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_ar.gz
# filter by AA
# filter eq Chain
# 193 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_as.gz
# filter by AA
# filter eq Chain
# 194 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_at.gz
# filter by AA
# filter eq Chain
# 195 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_au.gz
# filter by AA
# filter eq Chain
# 196 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_av.gz
# filter by AA
# filter eq Chain
# 197 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_aw.gz
# filter by AA
# filter eq Chain
# 198 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_ax.gz
# filter by AA
# filter eq Chain
# 199 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_ay.gz
# filter by AA
# filter eq Chain
# 200 ../data/pdb_str/cs219_hits/hits_xbg_cath_pairs_az.gz
# filter by AA
# filter eq Chain
# 201 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_aa.gz
# filter by AA
# filter eq Chain
# 202 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_ab.gz
# filter by AA
# filter eq Chain
# 203 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_ac.gz
# filter by AA
# filter eq Chain
# 204 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_ad.gz
# filter by AA
# filter eq Chain
# 205 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_ae.gz
# filter by AA
# filter eq Chain
# 206 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_af.gz
# filter by AA
# filter eq Chain
# 207 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_ag.gz
# filter by AA
# filter eq Chain
# 208 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_ah.gz
# filter by AA
# filter eq Chain
# 209 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_ai.gz
# filter by AA
# filter eq Chain
# 210 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_aj.gz
# filter by AA
# filter eq Chain
# 211 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_ak.gz
# filter by AA
# filter eq Chain
# 212 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_al.gz
# filter by AA
# filter eq Chain
# 213 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_am.gz
# filter by AA
# filter eq Chain
# 214 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_an.gz
# filter by AA
# filter eq Chain
# 215 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_ao.gz
# filter by AA
# filter eq Chain
# 216 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_ap.gz
# filter by AA
# filter eq Chain
# 217 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_aq.gz
# filter by AA
# filter eq Chain
# 218 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_ar.gz
# filter by AA
# filter eq Chain
# 219 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_as.gz
# filter by AA
# filter eq Chain
# 220 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_at.gz
# filter by AA
# filter eq Chain
# 221 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_au.gz
# filter by AA
# filter eq Chain
# 222 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_av.gz
# filter by AA
# filter eq Chain
# 223 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_aw.gz
# filter by AA
# filter eq Chain
# 224 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_ax.gz
# filter by AA
# filter eq Chain
# 225 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_ay.gz
# filter by AA
# filter eq Chain
# 226 ../data/pdb_str/cs219_hits/hits_xbh_cath_pairs_az.gz
# filter by AA
# filter eq Chain
# 227 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_aa.gz
# filter by AA
# filter eq Chain
# 228 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_ab.gz
# filter by AA
# filter eq Chain
# 229 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_ac.gz
# filter by AA
# filter eq Chain
# 230 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_ad.gz
# filter by AA
# filter eq Chain
# 231 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_ae.gz
# filter by AA
# filter eq Chain
# 232 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_af.gz
# filter by AA
# filter eq Chain
# 233 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_ag.gz
# filter by AA
# filter eq Chain
# 234 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_ah.gz
# filter by AA
# filter eq Chain
# 235 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_ai.gz
# filter by AA
# filter eq Chain
# 236 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_aj.gz
# filter by AA
# filter eq Chain
# 237 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_ak.gz
# filter by AA
# filter eq Chain
# 238 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_al.gz
# filter by AA
# filter eq Chain
# 239 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_am.gz
# filter by AA
# filter eq Chain
# 240 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_an.gz
# filter by AA
# filter eq Chain
# 241 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_ao.gz
# filter by AA
# filter eq Chain
# 242 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_ap.gz
# filter by AA
# filter eq Chain
# 243 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_aq.gz
# filter by AA
# filter eq Chain
# 244 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_ar.gz
# filter by AA
# filter eq Chain
# 245 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_as.gz
# filter by AA
# filter eq Chain
# 246 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_at.gz
# filter by AA
# filter eq Chain
# 247 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_au.gz
# filter by AA
# filter eq Chain
# 248 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_av.gz
# filter by AA
# filter eq Chain
# 249 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_aw.gz
# filter by AA
# filter eq Chain
# 250 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_ax.gz
# filter by AA
# filter eq Chain
# 251 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_ay.gz
# filter by AA
# filter eq Chain
# 252 ../data/pdb_str/cs219_hits/hits_xbi_cath_pairs_az.gz
# filter by AA
# filter eq Chain
# 253 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_aa.gz
# filter by AA
# filter eq Chain
# 254 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_ab.gz
# filter by AA
# filter eq Chain
# 255 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_ac.gz
# filter by AA
# filter eq Chain
# 256 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_ad.gz
# filter by AA
# filter eq Chain
# 257 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_ae.gz
# filter by AA
# filter eq Chain
# 258 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_af.gz
# filter by AA
# filter eq Chain
# 259 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_ag.gz
# filter by AA
# filter eq Chain
# 260 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_ah.gz
# filter by AA
# filter eq Chain
# 261 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_ai.gz
# filter by AA
# filter eq Chain
# 262 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_aj.gz
# filter by AA
# filter eq Chain
# 263 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_ak.gz
# filter by AA
# filter eq Chain
# 264 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_al.gz
# filter by AA
# filter eq Chain
# 265 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_am.gz
# filter by AA
# filter eq Chain
# 266 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_an.gz
# filter by AA
# filter eq Chain
# 267 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_ao.gz
# filter by AA
# filter eq Chain
# 268 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_ap.gz
# filter by AA
# filter eq Chain
# 269 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_aq.gz
# filter by AA
# filter eq Chain
# 270 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_ar.gz
# filter by AA
# filter eq Chain
# 271 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_as.gz
# filter by AA
# filter eq Chain
# 272 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_at.gz
# filter by AA
# filter eq Chain
# 273 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_au.gz
# filter by AA
# filter eq Chain
# 274 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_av.gz
# filter by AA
# filter eq Chain
# 275 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_aw.gz
# filter by AA
# filter eq Chain
# 276 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_ax.gz
# filter by AA
# filter eq Chain
# 277 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_ay.gz
# filter by AA
# filter eq Chain
# 278 ../data/pdb_str/cs219_hits/hits_xbj_cath_pairs_az.gz
# filter by AA
# filter eq Chain
# 279 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_aa.gz
# filter by AA
# filter eq Chain
# 280 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_ab.gz
# filter by AA
# filter eq Chain
# 281 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_ac.gz
# filter by AA
# filter eq Chain
# 282 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_ad.gz
# filter by AA
# filter eq Chain
# 283 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_ae.gz
# filter by AA
# filter eq Chain
# 284 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_af.gz
# filter by AA
# filter eq Chain
# 285 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_ag.gz
# filter by AA
# filter eq Chain
# 286 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_ah.gz
# filter by AA
# filter eq Chain
# 287 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_ai.gz
# filter by AA
# filter eq Chain
# 288 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_aj.gz
# filter by AA
# filter eq Chain
# 289 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_ak.gz
# filter by AA
# filter eq Chain
# 290 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_al.gz
# filter by AA
# filter eq Chain
# 291 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_am.gz
# filter by AA
# filter eq Chain
# 292 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_an.gz
# filter by AA
# filter eq Chain
# 293 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_ao.gz
# filter by AA
# filter eq Chain
# 294 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_ap.gz
# filter by AA
# filter eq Chain
# 295 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_aq.gz
# filter by AA
# filter eq Chain
# 296 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_ar.gz
# filter by AA
# filter eq Chain
# 297 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_as.gz
# filter by AA
# filter eq Chain
# 298 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_at.gz
# filter by AA
# filter eq Chain
# 299 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_au.gz
# filter by AA
# filter eq Chain
# 300 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_av.gz
# filter by AA
# filter eq Chain
# 301 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_aw.gz
# filter by AA
# filter eq Chain
# 302 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_ax.gz
# filter by AA
# filter eq Chain
# 303 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_ay.gz
# filter by AA
# filter eq Chain
# 304 ../data/pdb_str/cs219_hits/hits_xbk_cath_pairs_az.gz
# filter by AA
# filter eq Chain
# 305 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_aa.gz
# filter by AA
# filter eq Chain
# 306 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_ab.gz
# filter by AA
# filter eq Chain
# 307 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_ac.gz
# filter by AA
# filter eq Chain
# 308 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_ad.gz
# filter by AA
# filter eq Chain
# 309 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_ae.gz
# filter by AA
# filter eq Chain
# 310 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_af.gz
# filter by AA
# filter eq Chain
# 311 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_ag.gz
# filter by AA
# filter eq Chain
# 312 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_ah.gz
# filter by AA
# filter eq Chain
# 313 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_ai.gz
# filter by AA
# filter eq Chain
# 314 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_aj.gz
# filter by AA
# filter eq Chain
# 315 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_ak.gz
# filter by AA
# filter eq Chain
# 316 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_al.gz
# filter by AA
# filter eq Chain
# 317 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_am.gz
# filter by AA
# filter eq Chain
# 318 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_an.gz
# filter by AA
# filter eq Chain
# 319 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_ao.gz
# filter by AA
# filter eq Chain
# 320 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_ap.gz
# filter by AA
# filter eq Chain
# 321 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_aq.gz
# filter by AA
# filter eq Chain
# 322 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_ar.gz
# filter by AA
# filter eq Chain
# 323 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_as.gz
# filter by AA
# filter eq Chain
# 324 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_at.gz
# filter by AA
# filter eq Chain
# 325 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_au.gz
# filter by AA
# filter eq Chain
# 326 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_av.gz
# filter by AA
# filter eq Chain
# 327 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_aw.gz
# filter by AA
# filter eq Chain
# 328 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_ax.gz
# filter by AA
# filter eq Chain
# 329 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_ay.gz
# filter by AA
# filter eq Chain
# 330 ../data/pdb_str/cs219_hits/hits_xbl_cath_pairs_az.gz
# filter by AA
# filter eq Chain
# 331 ../data/pdb_str/cs219_hits/hits_xbm_cath_pairs_aa.gz
# filter by AA
# filter eq Chain
# 332 ../data/pdb_str/cs219_hits/hits_xbm_cath_pairs_ab.gz
# filter by AA
# filter eq Chain
# 333 ../data/pdb_str/cs219_hits/hits_xbm_cath_pairs_ac.gz
# filter by AA
# filter eq Chain
# 334 ../data/pdb_str/cs219_hits/hits_xbm_cath_pairs_ad.gz
# filter by AA
# filter eq Chain
# 335 ../data/pdb_str/cs219_hits/hits_xbm_cath_pairs_ae.gz
# filter by AA
# filter eq Chain
# 336 ../data/pdb_str/cs219_hits/hits_xbm_cath_pairs_af.gz
# filter by AA
# filter eq Chain
# 337 ../data/pdb_str/cs219_hits/hits_xbm_cath_pairs_ag.gz
# filter by AA
# filter eq Chain
# 338 ../data/pdb_str/cs219_hits/hits_xbm_cath_pairs_ah.gz
# filter by AA
# filter eq Chain
# 339 ../data/pdb_str/cs219_hits/hits_xbm_cath_pairs_ai.gz
# filter by AA
# filter eq Chain
# 340 ../data/pdb_str/cs219_hits/hits_xbm_cath_pairs_aj.gz
# filter by AA
# filter eq Chain
# 341 ../data/pdb_str/cs219_hits/hits_xbm_cath_pairs_ak.gz
# filter by AA
# filter eq Chain

# %%
source = "../data/pdb_str/statistics/temp/"
dfs = [ pd.read_csv("%s" % f)  for f in  files ]
df = pd.concat(dfs)
df = df.groupby("hit").N.sum().reset_index(name="N")
df.head()
# Out:
#      hit         N
# 0      !  23381223
# 1     !!    300564
# 2    !!!      2135
# 3   !!!!        39
# 4  !!!!/         1

# %%
df.to_csv("../data/pdb_str/statistics/cs219_histogram_count_by_hit.csv", index=False)

# %%
MK_HITS_DIR = "../data/pdb_str/m32k25_hits/"
files = [ "".join([MK_HITS_DIR, f]) for f in listdir(MK_HITS_DIR) ]
# Out:
#          x        y  hit_length                    hit
# 0  12asA00  132lA00           7                UUUUUUV
# 1  12asA00  153lA00          20   UUUUUUUUUUUUUUUUUUUU
# 2  12asA00  155cA00           9              KVUUUUUUU
# 3  12asA00  16pkA02          14         UUUUUUUUUUUUUU
# 4  12asA00  16vpA00          21  VUUUUUUUUUUUUUUUUUUUU

# %%
for f in files:
    _df = pd.read_csv(f)
    _df = _df[_df.hit == "AABLPWNAA"]
    if _df.shape[0] > 0:
        break

# %%
_df
# Out:
#               x        y  hit_length        hit
# 212035  1iwmA00  1u14A00           9  AABLPWNAA
