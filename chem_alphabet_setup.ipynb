# %%
import pandas as pd
from Bio import SeqIO
from os import listdir
from os.path import isfile, join
from Bio.SeqRecord import SeqRecord
from Bio.Seq import Seq

# %%
sauer = ["D","E"]
aliphatisch = ["A","G","I","L","V"]
amidisch = ["N", "Q"]
aromatisch = ["F","W","Y"]
basisch = ["R","H","K"]
hydroxyl = ["S","T"]
imino = ["P"]
schwefel = ["C","M"]

# %%
chem_alphabet = {
    "D":"s",
    "E":"s",
    "A":"a",
    "G":"a",
    "I":"a",
    "L":"a",
    "V":"a",
    "N":"m",
    "Q":"m",
    "F":"r",
    "W":"r",
    "Y":"r",
    "R":"b",
    "H":"b",
    "K":"b",
    "S":"h",
    "T":"h",
    "P":"i",
    "C":"w",
    "M":"w" ,
    "X":"x"   #The one-letter symbol for an undetermined amino acid is X
}

# %%
def readPDB(fasta):
    for record in SeqIO.parse("../data/pdb_str/fasta/%s" % fasta, "fasta"):
        pdb = list(record.seq)
    return pdb

def readFasta(d):
    for record in SeqIO.parse(d, "fasta"):
        pdb = "".join(list(record.seq))
    return pdb        

def map_alphabet(alphabet, seq):
    return [alphabet[s] for s in seq]

def convert_to_str(alphabet, filename):
    pdb = filename.split(".")[0]
    seq = "".join(map_alphabet(chem_alphabet, readPDB(filename)))
    return SeqRecord(Seq(seq), id=pdb, description="")

# %%
fasta_dir = "../data/pdb_str/fasta/"
chem_dir = "../data/pdb_str/chem/"
fasta_files = [  f for f in listdir("../data/pdb_str/fasta/") ]
fasta_files[1:4]
# Out:
# ['132lA00.fasta', '153lA00.fasta', '155cA00.fasta']

# %%
chem_seq = { f:convert_to_str(chem_alphabet, f) for f in fasta_files }
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-5b5c04380f5f> in <module>
# ----> 1 chem_seq = { f:convert_to_str(chem_alphabet, f) for f in fasta_files }
#
# <ipython-input-11-5b5c04380f5f> in <dictcomp>(.0)
# ----> 1 chem_seq = { f:convert_to_str(chem_alphabet, f) for f in fasta_files }
#
# <ipython-input-9-c958919c72d7> in convert_to_str(alphabet, filename)
#       9 def convert_to_str(alphabet, filename):
#      10     pdb = filename.split(".")[0]
# ---> 11     seq = "".join(map_alphabet(chem_alphabet, readPDB(filename)))
#      12     return SeqRecord(Seq(seq), id=pdb, description="")
#
# <ipython-input-9-c958919c72d7> in readPDB(fasta)
#       1 def readPDB(fasta):
# ----> 2     for record in SeqIO.parse("../data/pdb_str/fasta/%s" % fasta):
#       3         pdb = list(record.seq)
#       4     return pdb
#       5
#
# TypeError: parse() missing 1 required positional argument: 'format'

# %%
for k in chem_seq:
    with open("%s/%s" % (chem_dir, k), "w") as o:
        SeqIO.write(chem_seq[k], o, "fasta")

# %%
[ f for f in listdir(chem_dir) if len(readFasta("/".join([chem_dir, f]))) < 50 ]
# Out:
# ['1a1iA01.fasta',
#  '1a3pA00.fasta',
#  '1a5tA02.fasta',
#  '1a62A01.fasta',
#  '1afoA00.fasta',
#  '1aggA00.fasta',
#  '1agrH01.fasta',
#  '1ahlA00.fasta',
#  '1al0B00.fasta',
#  '1amlA00.fasta',
#  '1aooA00.fasta',
#  '1aq5A00.fasta',
#  '1aroP02.fasta',
#  '1autL01.fasta',
#  '1b01A00.fasta',
#  '1b8wA00.fasta',
#  '1b8xA03.fasta',
#  '1b9wA02.fasta',
#  '1b9xC02.fasta',
#  '1bazC00.fasta',
#  '1bbgA00.fasta',
#  '1bccD01.fasta',
#  '1bdsA00.fasta',
#  '1bg5A03.fasta',
#  '1bh9A00.fasta',
#  '1bhpA00.fasta',
#  '1bi6H00.fasta',
#  '1bjtA01.fasta',
#  '1bpeA01.fasta',
#  '1bvsF03.fasta',
#  '1bzkA00.fasta',
#  '1cf4B00.fasta',
#  '1cfhA00.fasta',
#  '1ci6B00.fasta',
#  '1cixA00.fasta',
#  '1co4A00.fasta',
#  '1cp9A02.fasta',
#  '1crnA00.fasta',
#  '1csbA01.fasta',
#  '1cukA03.fasta',
#  '1cwxA00.fasta',
#  '1czqA00.fasta',
#  '1d4vA02.fasta',
#  '1d4vA03.fasta',
#  '1d5sB00.fasta',
#  '1d66B02.fasta',
#  '1d6gA00.fasta',
#  '1dd4D01.fasta',
#  '1devB00.fasta',
#  '1dgwY01.fasta',
#  '1dipA01.fasta',
#  '1dqbA01.fasta',
#  '1dv0A00.fasta',
#  '1dx5I02.fasta',
#  '1dx7A00.fasta',
#  '1e0aB00.fasta',
#  '1e0fI01.fasta',
#  '1e0gA00.fasta',
#  '1e3oC02.fasta',
#  '1e88A03.fasta',
#  '1e8pA00.fasta',
#  '1ebdC00.fasta',
#  '1ed7A00.fasta',
#  '1edxA00.fasta',
#  '1efuB04.fasta',
#  '1eg3A01.fasta',
#  '1ehsA00.fasta',
#  '1ekeB02.fasta',
#  '1el6A02.fasta',
#  '1emnA01.fasta',
#  '1emnA02.fasta',
#  '1ep3B03.fasta',
#  '1eptA00.fasta',
#  '1eqgA01.fasta',
#  '1erdA00.fasta',
#  '1f5tA02.fasta',
#  '1f7eA00.fasta',
#  '1fd3A00.fasta',
#  '1fdoA05.fasta',
#  '1fi8D00.fasta',
#  '1flcA01.fasta',
#  '1fleI00.fasta',
#  '1fs0E02.fasta',
#  '1ft8E00.fasta',
#  '1fzcC03.fasta',
#  '1g1iA00.fasta',
#  '1g29102.fasta',
#  '1g2cB00.fasta',
#  '1g2dC03.fasta',
#  '1g3iW02.fasta',
#  '1g3jB00.fasta',
#  '1g44C04.fasta',
#  '1g6uA00.fasta',
#  '1g8mA01.fasta',
#  '1g9pA00.fasta',
#  '1gdtB02.fasta',
#  '1gdtB03.fasta',
#  '1gkuB01.fasta',
#  '1gl9B01.fasta',
#  '1go3F02.fasta',
#  '1gp8A00.fasta',
#  '1gptA00.fasta',
#  '1gpzA02.fasta',
#  '1gv2A02.fasta',
#  '1gw3A00.fasta',
#  '1gzdA03.fasta',
#  '1h3oA00.fasta',
#  '1h59B00.fasta',
#  '1h5wB03.fasta',
#  '1h6uA01.fasta',
#  '1h6wA01.fasta',
#  '1h6wA02.fasta',
#  '1h7dA00.fasta',
#  '1h8pA01.fasta',
#  '1hgvA00.fasta',
#  '1hj0A00.fasta',
#  '1hmvB02.fasta',
#  '1hnrA00.fasta',
#  '1hr5A00.fasta',
#  '1hwtC02.fasta',
#  '1hxdA03.fasta',
#  '1hy9A00.fasta',
#  '1hykA00.fasta',
#  '1i2vA00.fasta',
#  '1i39A02.fasta',
#  '1i7wB00.fasta',
#  '1i94M02.fasta',
#  '1icaA00.fasta',
#  '1ifpA00.fasta',
#  '1ijdA00.fasta',
#  '1ijdB00.fasta',
#  '1im2A02.fasta',
#  '1im4A03.fasta',
#  '1inpA01.fasta',
#  '1irqA00.fasta',
#  '1irxA02.fasta',
#  '1irxA03.fasta',
#  '1iw7D11.fasta',
#  '1iz3A02.fasta',
#  '1iznB03.fasta',
#  '1j09A04.fasta',
#  '1j2jB00.fasta',
#  '1jb0J00.fasta',
#  '1jb0K00.fasta',
#  '1jekA00.fasta',
#  '1ji8A01.fasta',
#  '1jjoA00.fasta',
#  '1jjsA00.fasta',
#  '1jkzA00.fasta',
#  '1jmkC02.fasta',
#  '1jmmA01.fasta',
#  '1jo6A00.fasta',
#  '1jqvA02.fasta',
#  '1jrfA00.fasta',
#  '1jusD01.fasta',
#  '1jy2N00.fasta',
#  '1jy2S00.fasta',
#  '1k04A01.fasta',
#  '1k1vA00.fasta',
#  '1k3eA01.fasta',
#  '1k6yA01.fasta',
#  '1k7tA01.fasta',
#  '1k8kA02.fasta',
#  '1kbeA00.fasta',
#  '1kbhA00.fasta',
#  '1kf6A04.fasta',
#  '1kg1A02.fasta',
#  '1kilE00.fasta',
#  '1kj6A00.fasta',
#  '1kmiZ01.fasta',
#  '1korA03.fasta',
#  '1kqfB03.fasta',
#  '1krlA00.fasta',
#  '1kv4A00.fasta',
#  '1kyqA02.fasta',
#  '1l0nK00.fasta',
#  '1l1oC02.fasta',
#  '1l3yA00.fasta',
#  '1l6eA00.fasta',
#  '1l8qA02.fasta',
#  '1lcuA02.fasta',
#  '1lghB00.fasta',
#  '1lmmA01.fasta',
#  '1lqlA01.fasta',
#  '1lqsL02.fasta',
#  '1ltbC00.fasta',
#  '1ltlA03.fasta',
#  '1m56D00.fasta',
#  '1m7lA00.fasta',
#  '1m8oB00.fasta',
#  '1m93A00.fasta',
#  '1m9oA00.fasta',
#  '1mbmB03.fasta',
#  '1mfzA02.fasta',
#  '1mhwC00.fasta',
#  '1mkcA00.fasta',
#  '1mkmA02.fasta',
#  '1ml8A01.fasta',
#  '1mslA02.fasta',
#  '1mt1A00.fasta',
#  '1mvfD00.fasta',
#  '1mz9A00.fasta',
#  '1n0zA00.fasta',
#  '1n2dC00.fasta',
#  '1n4nA00.fasta',
#  '1n7dA02.fasta',
#  '1n7dA03.fasta',
#  '1n7dA07.fasta',
#  '1nbwA05.fasta',
#  '1ncqD00.fasta',
#  '1ncsA00.fasta',
#  '1nd9A00.fasta',
#  '1ne5A00.fasta',
#  '1ng2A01.fasta',
#  '1nh2B00.fasta',
#  '1nh2D02.fasta',
#  '1ni8A00.fasta',
#  '1np6A02.fasta',
#  '1nt2A01.fasta',
#  '1nuiA01.fasta',
#  '1nvpB00.fasta',
#  '1nvpD02.fasta',
#  '1nxuA03.fasta',
#  '1o9aA01.fasta',
#  '1o9gA02.fasta',
#  '1ofcX03.fasta',
#  '1ohnA00.fasta',
#  '1oipA02.fasta',
#  '1ojlA03.fasta',
#  '1olgA00.fasta',
#  '1omiA02.fasta',
#  '1oryB00.fasta',
#  '1otrA00.fasta',
#  '1owaA01.fasta',
#  '1owbA01.fasta',
#  '1oxxK02.fasta',
#  '1oxxK03.fasta',
#  '1ozhA03.fasta',
#  '1p9gA00.fasta',
#  '1pfiA00.fasta',
#  '1pgjA03.fasta',
#  '1pjqA02.fasta',
#  '1pnkA02.fasta',
#  '1ppjI00.fasta',
#  '1pv0A01.fasta',
#  '1pycA00.fasta',
#  '1pzqA01.fasta',
#  '1pzxA02.fasta',
#  '1q16A01.fasta',
#  '1q16A03.fasta',
#  '1q16A09.fasta',
#  '1q5vB01.fasta',
#  '1qdpA00.fasta',
#  '1qexA01.fasta',
#  '1qgkB00.fasta',
#  '1qhkA00.fasta',
#  '1qo0D02.fasta',
#  '1qqp400.fasta',
#  '1qzeA02.fasta',
#  '1r5sA01.fasta',
#  '1r89A04.fasta',
#  '1r8eA03.fasta',
#  '1rajA01.fasta',
#  '1rc9A02.fasta',
#  '1rfhA01.fasta',
#  '1rjmA02.fasta',
#  '1rmdA02.fasta',
#  '1ro2A03.fasta',
#  '1rp3B02.fasta',
#  '1rp5A01.fasta',
#  '1rr7A01.fasta',
#  '1rr7A02.fasta',
#  '1s3jA01.fasta',
#  '1s3jA03.fasta',
#  '1s7mA03.fasta',
#  '1s7mB01.fasta',
#  '1sh1A00.fasta',
#  '1slqE02.fasta',
#  '1sqgA02.fasta',
#  '1sr8A01.fasta',
#  '1sr9B03.fasta',
#  '1sslA00.fasta',
#  '1t0fC00.fasta',
#  '1t3bA01.fasta',
#  '1t3uA01.fasta',
#  '1t3uA02.fasta',
#  '1t6aA01.fasta',
#  '1tf6D01.fasta',
#  '1ti5A00.fasta',
#  '1tk7A01.fasta',
#  '1tr8A01.fasta',
#  '1tr8A02.fasta',
#  '1twfI01.fasta',
#  '1twfL00.fasta',
#  '1u57A00.fasta',
#  '1u5kA03.fasta',
#  '1u5mA01.fasta',
#  '1u78A02.fasta',
#  '1u96A01.fasta',
#  '1uelB00.fasta',
#  '1ufiC01.fasta',
#  '1usdA00.fasta',
#  '1v1hA02.fasta',
#  '1v4pA02.fasta',
#  '1v5eA04.fasta',
#  '1v92A00.fasta',
#  '1vegA01.fasta',
#  '1vf5Q01.fasta',
#  '1vi0A01.fasta',
#  '1vlaA01.fasta',
#  '1vloA03.fasta',
#  '1vpcA00.fasta',
#  '1vpuA00.fasta',
#  '1vq8200.fasta',
#  '1vq8P02.fasta',
#  '1vs5U01.fasta',
#  '1vsaY01.fasta',
#  '1vwxI02.fasta',
#  '1vx7302.fasta',
#  '1vx7Q02.fasta',
#  '1vziA01.fasta',
#  '1w4rA02.fasta',
#  '1w59A01.fasta',
#  '1w96A02.fasta',
#  '1w9zA01.fasta',
#  '1wa9B03.fasta',
#  '1wazA00.fasta',
#  '1wfhA01.fasta',
#  '1wjpA01.fasta',
#  '1wjpA02.fasta',
#  '1wjpA03.fasta',
#  '1wmkA03.fasta',
#  '1wmtA00.fasta',
#  '1wmvA01.fasta',
#  '1wsrA03.fasta',
#  '1wtjA03.fasta',
#  '1wvfA04.fasta',
#  '1wvvB01.fasta',
#  '1wxnA00.fasta',
#  '1wzoA01.fasta',
#  '1x0tA02.fasta',
#  '1x32A00.fasta',
#  '1x3wB01.fasta',
#  '1x58A01.fasta',
#  '1x5wA02.fasta',
#  '1x74A05.fasta',
#  '1x93A01.fasta',
#  '1xc5A01.fasta',
#  '1xezA03.fasta',
#  '1xhcA03.fasta',
#  '1xi7A00.fasta',
#  '1xrdA01.fasta',
#  '1xutA01.fasta',
#  '1xx6A02.fasta',
#  '1y07B01.fasta',
#  '1y6uA01.fasta',
#  '1y7mA01.fasta',
#  '1y7xA01.fasta',
#  '1y8aA03.fasta',
#  '1y8gA03.fasta',
#  '1y9bB01.fasta',
#  '1y9bB02.fasta',
#  '1yo8A03.fasta',
#  '1ysmA01.fasta',
#  '1yukA02.fasta',
#  '1yukB02.fasta',
#  '1yuzA02.fasta',
#  '1yx2A03.fasta',
#  '1yx3A01.fasta',
#  '1yycA01.fasta',
#  '1yzbA02.fasta',
#  '1yzmA00.fasta',
#  '1z2iA03.fasta',
#  '1z47A02.fasta',
#  '1z47A03.fasta',
#  '1z8rA01.fasta',
#  '1z9iA01.fasta',
#  '1zk8A01.fasta',
#  '1zkcB02.fasta',
#  '1zlhB01.fasta',
#  '1zmbA02.fasta',
#  '1zmeC01.fasta',
#  '1zmeC02.fasta',
#  '1zoyC01.fasta',
#  '1zrtD02.fasta',
#  '1zrtE01.fasta',
#  '1zy9A03.fasta',
#  '2a25A01.fasta',
#  '2a2bA00.fasta',
#  '2a6qA01.fasta',
#  '2a6tB01.fasta',
#  '2adlA01.fasta',
#  '2aklA01.fasta',
#  '2arhA02.fasta',
#  '2aucB01.fasta',
#  '2axcA02.fasta',
#  '2b39A07.fasta',
#  '2b68A01.fasta',
#  '2b9dA01.fasta',
#  '2b9kA00.fasta',
#  '2ba0A01.fasta',
#  '2ba3A01.fasta',
#  '2basA02.fasta',
#  '2beqD00.fasta',
#  '2bhvA02.fasta',
#  '2bhyA03.fasta',
#  '2bjoA01.fasta',
#  '2bouA01.fasta',
#  '2bouA02.fasta',
#  '2bsfA01.fasta',
#  '2c42A04.fasta',
#  '2c9wA02.fasta',
#  '2cb9A02.fasta',
#  '2cg7A01.fasta',
#  '2cg7A02.fasta',
#  '2ci8A02.fasta',
#  '2cjsC01.fasta',
#  '2ckaA01.fasta',
#  '2cobA01.fasta',
#  '2cq7A00.fasta',
#  '2cr8A01.fasta',
#  '2cupA02.fasta',
#  '2d9tA01.fasta',
#  '2da3A01.fasta',
#  '2dduA02.fasta',
#  '2debA01.fasta',
#  '2dfuA01.fasta',
#  '2dgyA02.fasta',
#  '2di0A01.fasta',
#  '2dipA01.fasta',
#  '2dlkA01.fasta',
#  '2dlkA02.fasta',
#  '2dlqA03.fasta',
#  '2drpA01.fasta',
#  '2drpA02.fasta',
#  '2ds3A02.fasta',
#  '2ds5A00.fasta',
#  '2e10A02.fasta',
#  '2e19A01.fasta',
#  '2e1mA04.fasta',
#  '2e1mB02.fasta',
#  '2e2fA00.fasta',
#  '2e45A01.fasta',
#  '2e5yA02.fasta',
#  '2e9hA02.fasta',
#  '2ea6A01.fasta',
#  '2eayB02.fasta',
#  '2ebqA00.fasta',
#  '2eciA01.fasta',
#  '2egtA01.fasta',
#  '2ej9A02.fasta',
#  '2ekfA01.fasta',
#  '2epcA01.fasta',
#  '2eppA01.fasta',
#  '2erlA00.fasta',
#  '2f2hA03.fasta',
#  '2f4lA02.fasta',
#  '2f5zK00.fasta',
#  '2fbmA02.fasta',
#  '2fd5A01.fasta',
#  '2fd6A01.fasta',
#  '2fl4A01.fasta',
#  '2fmlA01.fasta',
#  '2fsfB02.fasta',
#  '2fx0A01.fasta',
#  '2g3aA01.fasta',
#  '2g3qA00.fasta',
#  '2g5dA03.fasta',
#  '2g8yA03.fasta',
#  '2ga1A01.fasta',
#  '2ganA02.fasta',
#  '2gliA01.fasta',
#  '2gliA04.fasta',
#  '2gm6A01.fasta',
#  '2gpeD01.fasta',
#  '2gu2A02.fasta',
#  '2gviA03.fasta',
#  '2h8pD00.fasta',
#  '2haxA01.fasta',
#  '2hd0A02.fasta',
#  '2hepA00.fasta',
#  '2hirA00.fasta',
#  '2hjqA01.fasta',
#  '2hr3A01.fasta',
#  '2hr3A03.fasta',
#  '2hrvA01.fasta',
#  '2hyjA01.fasta',
#  '2i15A01.fasta',
#  '2i3tD01.fasta',
#  '2i7nA03.fasta',
#  '2i8dA02.fasta',
#  '2ibdA01.fasta',
#  '2id3A01.fasta',
#  '2idbA03.fasta',
#  '2im9A03.fasta',
#  '2ipqX01.fasta',
#  '2ipxA01.fasta',
#  '2iz4A01.fasta',
#  '2iz4A02.fasta',
#  '2j58A04.fasta',
#  '2j59M02.fasta',
#  '2j7jA03.fasta',
#  '2j88H02.fasta',
#  '2j8pA00.fasta',
#  '2j9uB00.fasta',
#  '2jdiH02.fasta',
#  '2jkvA03.fasta',
#  '2jl6101.fasta',
#  '2jl8102.fasta',
#  '2jm4A00.fasta',
#  '2jmqA01.fasta',
#  '2jmsA01.fasta',
#  '2jr3A00.fasta',
#  '2jraA01.fasta',
#  '2jubA02.fasta',
#  '2jwaA00.fasta',
#  '2jwgA00.fasta',
#  '2jwhA00.fasta',
#  '2jx8A00.fasta',
#  '2k1aA00.fasta',
#  '2k2dA00.fasta',
#  '2k4dA01.fasta',
#  '2k7iA01.fasta',
#  '2k7vB01.fasta',
#  '2k9jB00.fasta',
#  '2k9qA01.fasta',
#  '2k9qA02.fasta',
#  '2k9yA00.fasta',
#  '2ka6B00.fasta',
#  '2kb9A00.fasta',
#  '2kc6A01.fasta',
#  '2kelA00.fasta',
#  '2kizA01.fasta',
#  '2kldA01.fasta',
#  '2kn1A00.fasta',
#  '2kngA01.fasta',
#  '2koeA00.fasta',
#  '2kpiA01.fasta',
#  '2ks1B01.fasta',
#  '2kswA01.fasta',
#  '2kxqA01.fasta',
#  '2l0zA00.fasta',
#  '2l14B00.fasta',
#  '2l5gB00.fasta',
#  '2l6oA02.fasta',
#  '2l8tB01.fasta',
#  '2l92A01.fasta',
#  '2l9sA00.fasta',
#  '2lbcA01.fasta',
#  '2lceA01.fasta',
#  '2lcqA02.fasta',
#  '2lfuA01.fasta',
#  '2lg4A00.fasta',
#  '2lhtA02.fasta',
#  '2liyA00.fasta',
#  '2ljlA01.fasta',
#  '2lkmA01.fasta',
#  '2llkA01.fasta',
#  '2lmzA00.fasta',
#  '2lnhC00.fasta',
#  '2lnzA00.fasta',
#  '2lo0A00.fasta',
#  '2lo3A01.fasta',
#  '2lojA01.fasta',
#  '2lt8A01.fasta',
#  '2luyA02.fasta',
#  '2lvaA01.fasta',
#  '2lvhA00.fasta',
#  '2lvsA02.fasta',
#  '2lwlA00.fasta',
#  '2m0bA00.fasta',
#  '2m0pA00.fasta',
#  '2m1sA01.fasta',
#  '2m5zA00.fasta',
#  '2m6nA00.fasta',
#  '2m6pA00.fasta',
#  '2m9aA03.fasta',
#  '2mjkA00.fasta',
#  '2mknA00.fasta',
#  '2mn3A00.fasta',
#  '2mr9A00.fasta',
#  '2mvtA00.fasta',
#  '2mysA01.fasta',
#  '2nabA01.fasta',
#  '2nydA02.fasta',
#  '2nz2A03.fasta',
#  '2o01J01.fasta',
#  '2o01N01.fasta',
#  '2o3jA02.fasta',
#  '2o5rA04.fasta',
#  '2oarA02.fasta',
#  '2odrC01.fasta',
#  '2odrD03.fasta',
#  '2oq1A02.fasta',
#  '2orpA03.fasta',
#  '2outA02.fasta',
#  '2oyhE01.fasta',
#  '2ozkA01.fasta',
#  '2p0xA01.fasta',
#  '2p10A02.fasta',
#  '2p1jA02.fasta',
#  '2p1oB01.fasta',
#  '2p3yA01.fasta',
#  '2p5zX03.fasta',
#  '2p63A01.fasta',
#  '2p7jB01.fasta',
#  '2p81A01.fasta',
#  '2p90A02.fasta',
#  '2pajA03.fasta',
#  '2pbzA03.fasta',
#  '2pfxA01.fasta',
#  '2pjuD03.fasta',
#  '2pm9A02.fasta',
#  '2pmzF02.fasta',
#  '2pn0A01.fasta',
#  '2pp6A01.fasta',
#  '2pptA01.fasta',
#  '2pspA02.fasta',
#  '2pw9A01.fasta',
#  '2py5A04.fasta',
#  '2py5A05.fasta',
#  '2py5A06.fasta',
#  '2q2eB04.fasta',
#  '2q2kA00.fasta',
#  '2qcvA02.fasta',
#  '2qh7B01.fasta',
#  '2qhoD00.fasta',
#  '2qiwA02.fasta',
#  '2qkdA01.fasta',
#  '2qlvB02.fasta',
#  '2qq8A01.fasta',
#  '2qr4A02.fasta',
#  '2qr6A01.fasta',
#  '2qrdB01.fasta',
#  '2qrvD02.fasta',
#  '2qsfA03.fasta',
#  '2qsiA02.fasta',
#  '2r01A02.fasta',
#  '2r1fA01.fasta',
#  '2r1fA03.fasta',
#  '2r3sA02.fasta',
#  '2r44A01.fasta',
#  '2r7fA03.fasta',
#  '2raeA01.fasta',
#  '2rblA01.fasta',
#  '2re3A03.fasta',
#  '2rh0A02.fasta',
#  '2rijA02.fasta',
#  '2rjzA01.fasta',
#  '2rngA01.fasta',
#  '2rngA02.fasta',
#  '2rqyA02.fasta',
#  '2rsiA02.fasta',
#  '2rsiA03.fasta',
#  '2uuxA01.fasta',
#  '2uwiA02.fasta',
#  '2v4jC01.fasta',
#  '2v7qI00.fasta',
#  '2v7qJ00.fasta',
#  '2v89A01.fasta',
#  '2vf1A01.fasta',
#  '2vf1A02.fasta',
#  '2vf7A05.fasta',
#  '2vfrA05.fasta',
#  '2vhoM02.fasta',
#  '2vl6A03.fasta',
#  '2vqrA02.fasta',
#  '2vrsC01.fasta',
#  '2vugA05.fasta',
#  '2w00A06.fasta',
#  '2w02B04.fasta',
#  '2w0tA00.fasta',
#  '2w82A02.fasta',
#  '2w86A03.fasta',
#  '2w9uA00.fasta',
#  '2wadA01.fasta',
#  '2wdqA04.fasta',
#  '2wg5F01.fasta',
#  '2wmmA01.fasta',
#  '2wpvB01.fasta',
#  '2wqiB00.fasta',
#  '2wscH01.fasta',
#  '2wvfA01.fasta',
#  '2wzpP04.fasta',
#  '2x26B03.fasta',
#  '2x2zD03.fasta',
#  '2x49A02.fasta',
#  '2x7rB00.fasta',
#  '2xauA04.fasta',
#  '2xf5A00.fasta',
#  '2xjpA02.fasta',
#  '2xkoC01.fasta',
#  '2xljA02.fasta',
#  '2xokI00.fasta',
#  '2xrcA02.fasta',
#  '2xv4S04.fasta',
#  '2y8nB01.fasta',
#  '2y8nB02.fasta',
#  '2y9yA03.fasta',
#  '2ykoA01.fasta',
#  '2ymkA01.fasta',
#  '2ymyB00.fasta',
#  '2ynzC03.fasta',
#  '2yo2A03.fasta',
#  '2yq3A03.fasta',
#  '2yreA02.fasta',
#  '2yrkA01.fasta',
#  '2yrmA01.fasta',
#  '2yshA01.fasta',
#  '2ysiA01.fasta',
#  '2yt4A01.fasta',
#  '2yvrA00.fasta',
#  '2yxlA02.fasta',
#  '2z04B02.fasta',
#  '2z2mD02.fasta',
#  '2zixA01.fasta',
#  '2zjsE00.fasta',
#  '2znhA03.fasta',
#  '2zo4A02.fasta',
#  '2ztbA03.fasta',
#  '2zu0D00.fasta',
#  '3a2aA00.fasta',
#  '3a43B02.fasta',
#  '3al8B02.fasta',
#  '3asiA02.fasta',
#  '3b0bC02.fasta',
#  '3b4sA01.fasta',
#  '3b4sA02.fasta',
#  '3b8eB00.fasta',
#  '3bbzA00.fasta',
#  '3bf5A02.fasta',
#  '3bfmA02.fasta',
#  '3bg1B01.fasta',
#  '3bg3A04.fasta',
#  '3bl4A02.fasta',
#  '3brcA01.fasta',
#  '3bwvA02.fasta',
#  '3bxjA01.fasta',
#  '3bxwA01.fasta',
#  '3by6A02.fasta',
#  '3c1dA02.fasta',
#  '3c1dA03.fasta',
#  '3c57B00.fasta',
#  '3c6mC01.fasta',
#  '3c8vA04.fasta',
#  '3ce2A02.fasta',
#  '3cf6E01.fasta',
#  '3ci0J02.fasta',
#  '3ci9A00.fasta',
#  '3cj8A01.fasta',
#  '3clqB01.fasta',
#  '3cngA01.fasta',
#  '3cs5A00.fasta',
#  '3cz6A02.fasta',
#  '3d00A02.fasta',
#  '3d31A02.fasta',
#  '3d55C02.fasta',
#  '3d5lA02.fasta',
#  '3d6wA02.fasta',
#  '3dcfA01.fasta',
#  '3dclA03.fasta',
#  '3ddtA00.fasta',
#  '3demA02.fasta',
#  '3df7A03.fasta',
#  '3dfgA01.fasta',
#  '3dfgA03.fasta',
#  '3dkqA02.fasta',
#  '3do9C02.fasta',
#  '3doaA03.fasta',
#  '3dteA02.fasta',
#  '3e21A00.fasta',
#  '3e2dA04.fasta',
#  '3e35A02.fasta',
#  '3e46A02.fasta',
#  '3e59B02.fasta',
#  '3eerA01.fasta',
#  '3effK02.fasta',
#  '3eg5B01.fasta',
#  '3eh5B01.fasta',
#  '3ep6B01.fasta',
#  '3ewkA02.fasta',
#  '3f0cA01.fasta',
#  '3f0zA03.fasta',
#  '3f2bA05.fasta',
#  '3fanA03.fasta',
#  '3fbyA01.fasta',
#  '3fcsD04.fasta',
#  '3fcsD05.fasta',
#  '3fdjA02.fasta',
#  '3fduA02.fasta',
#  '3fgaD00.fasta',
#  '3fi7A02.fasta',
#  '3fj5A01.fasta',
#  '3fj5A02.fasta',
#  '3fmtE01.fasta',
#  '3fndA02.fasta',
#  '3fs8A02.fasta',
#  '3fsyA02.fasta',
#  '3ft7B00.fasta',
#  '3fvqA02.fasta',
#  '3fwlA01.fasta',
#  '3g2mB01.fasta',
#  '3g3zA01.fasta',
#  '3g5oA01.fasta',
#  '3g9rA00.fasta',
#  '3gbnL02.fasta',
#  '3gl6A01.fasta',
#  '3gqcA02.fasta',
#  '3gqhA02.fasta',
#  '3gr0D01.fasta',
#  '3gw6A04.fasta',
#  '3h02A02.fasta',
#  '3h25A02.fasta',
#  '3h37A04.fasta',
#  '3h5tA01.fasta',
#  '3h99A02.fasta',
#  '3he4A00.fasta',
#  '3he4B00.fasta',
#  '3hg9A02.fasta',
#  '3hh2D03.fasta',
#  '3hphB01.fasta',
#  '3hryA01.fasta',
#  '3hrzC01.fasta',
#  '3hzjC01.fasta',
#  '3i38I02.fasta',
#  '3ic7A02.fasta',
#  '3ieyA01.fasta',
#  '3if4A01.fasta',
#  '3if4A02.fasta',
#  '3imiB02.fasta',
#  '3in6A01.fasta',
#  '3ip4C01.fasta',
#  '3ir9A01.fasta',
#  '3jcuO02.fasta',
#  '3jr7A02.fasta',
#  '3k2oA02.fasta',
#  '3k2tA01.fasta',
#  '3k3wA02.fasta',
#  '3k59A06.fasta',
#  '3k6qA01.fasta',
#  '3k6sH04.fasta',
#  '3k9xC01.fasta',
#  '3k9xC02.fasta',
#  '3kezA02.fasta',
#  '3kfuG01.fasta',
#  '3kfuG02.fasta',
#  '3kihC01.fasta',
#  '3knuD02.fasta',
#  '3kpeA00.fasta',
#  '3kqgA01.fasta',
#  '3kvpA00.fasta',
#  '3kxrA01.fasta',
#  '3l09A03.fasta',
#  '3l0oA01.fasta',
#  '3l4gC02.fasta',
#  '3l4yA01.fasta',
#  '3lb6C03.fasta',
#  '3ljkA03.fasta',
#  '3lx7A01.fasta',
#  '3m7nA03.fasta',
#  '3m91A00.fasta',
#  '3m9qA02.fasta',
#  '3mcxA02.fasta',
#  '3mekA02.fasta',
#  '3mhdD02.fasta',
#  '3mhsC01.fasta',
#  '3mhsC02.fasta',
#  '3mlqH00.fasta',
#  '3mqgA02.fasta',
#  '3mudD00.fasta',
#  '3mujA02.fasta',
#  '3myvA02.fasta',
#  '3mzkB01.fasta',
#  '3n3fA01.fasta',
#  '3nfqA01.fasta',
#  '3nggB00.fasta',
#  '3njaA02.fasta',
#  '3o2zG01.fasta',
#  '3o6qA01.fasta',
#  '3o6qD01.fasta',
#  '3ocfB03.fasta',
#  '3ogkB01.fasta',
#  '3ol0B00.fasta',
#  '3ol2B02.fasta',
#  '3oouA02.fasta',
#  '3ox6E02.fasta',
#  '3oymA04.fasta',
#  '3p2nB01.fasta',
#  '3pehA02.fasta',
#  '3pjvD02.fasta',
#  '3pl2A02.fasta',
#  '3pl5A02.fasta',
#  '3plnA02.fasta',
#  '3pm9A05.fasta',
#  '3pmiA02.fasta',
#  '3pqhA02.fasta',
#  '3prbA02.fasta',
#  '3q10D02.fasta',
#  '3q23A06.fasta',
#  '3qd6R02.fasta',
#  '3qdrB00.fasta',
#  '3qi7A03.fasta',
#  '3qkiA03.fasta',
#  '3qoqA00.fasta',
#  '3qwuA01.fasta',
#  '3qyfA02.fasta',
#  '3r4yA01.fasta',
#  '3r5dA02.fasta',
#  '3rkxA03.fasta',
#  '3rwrB02.fasta',
#  '3s6n201.fasta',
#  '3s6xC03.fasta',
#  '3sf4D00.fasta',
#  '3sobB02.fasta',
#  '3ssuA00.fasta',
#  '3swyA00.fasta',
#  '3tbxB00.fasta',
#  '3tndB01.fasta',
#  '3tvmE02.fasta',
#  '3u50C02.fasta',
#  '3u5cE04.fasta',
#  '3u5eI02.fasta',
#  '3u5eW02.fasta',
#  '3ufeB01.fasta',
#  '3ujhA03.fasta',
#  '3uk3D02.fasta',
#  '3ukvC01.fasta',
#  '3uoeA03.fasta',
#  '3v64C01.fasta',
#  '3vd6C01.fasta',
#  '3vdpA02.fasta',
#  '3vhtB02.fasta',
#  '3vk6A02.fasta',
#  '3vmaA01.fasta',
#  '3vopC00.fasta',
#  '3vtnA01.fasta',
#  '3vtpC00.fasta',
#  '3vw4A02.fasta',
#  '3w7tA04.fasta',
#  '3wknF00.fasta',
#  '3wmm000.fasta',
#  '3wvtA02.fasta',
#  '3zleA03.fasta',
#  '4a0tA02.fasta',
#  '4a17H02.fasta',
#  '4ae2C01.fasta',
#  '4aeqA01.fasta',
#  '4amcA01.fasta',
#  '4aybA06.fasta',
#  '4aybP00.fasta',
#  '4b08A06.fasta',
#  '4b8cD03.fasta',
#  '4b8vA03.fasta',
#  '4bbyA02.fasta',
#  '4bbyA06.fasta',
#  '4bkxA02.fasta',
#  '4bpeW04.fasta',
#  '4bszA03.fasta',
#  '4c7nA00.fasta',
#  '4c7rA02.fasta',
#  '4cc0B02.fasta',
#  '4dbgB03.fasta',
#  '4dckA02.fasta',
#  '4dgwB01.fasta',
#  '4djgB00.fasta',
#  '4dmiC01.fasta',
#  '4ds7E00.fasta',
#  '4dzoB01.fasta',
#  '4em6A03.fasta',
#  '4emcC01.fasta',
#  '4eozB03.fasta',
#  '4eqqA02.fasta',
#  '4f55A02.fasta',
#  '4f6mA01.fasta',
#  '4f6mA03.fasta',
#  '4f6rC01.fasta',
#  '4f9cB02.fasta',
#  '4fo0A02.fasta',
#  '4fvmA04.fasta',
#  '4gdoA00.fasta',
#  '4gipE04.fasta',
#  '4glxA05.fasta',
#  '4gnsA01.fasta',
#  '4gu4A01.fasta',
#  '4gv5A00.fasta',
#  '4gz8A02.fasta',
#  '4hb1A00.fasta',
#  '4hh2A02.fasta',
#  '4hizA01.fasta',
#  '4hytB01.fasta',
#  '4i6jB01.fasta',
#  '4i7zC03.fasta',
#  '4ifdK01.fasta',
#  '4ijdA02.fasta',
#  '4il6X00.fasta',
#  '4iqjM02.fasta',
#  '4izbB02.fasta',
#  '4j8zA02.fasta',
#  '4ja3A02.fasta',
#  '4jbzA03.fasta',
#  ...]
