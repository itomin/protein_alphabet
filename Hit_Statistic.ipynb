# %%
import pandas as pd
from Bio import SeqIO
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
sns.set(rc={'figure.figsize':(16,10)})

# %%
df = pd.read_csv("../data/pdb_str/part-r-00000-be9d15c5-c7dd-48bd-bbc1-27879ce81b6a.csv",  \
                sep=",", escapechar="\\", header=None,  \
                names=["hit", "pdb", "c", "a", "t", "h", "N"])

# %%
df[["hit", "pdb", "N"]].head()
# Out:
#       hit       pdb  N
# 0  ²²√√²²  3pf8:A00  6
# 1  ²²√√²²  3s4l:A00  6
# 2   √²≈√∞  1f89:A00  5
# 3   √²≈√∞  2wtm:A00  5
# 4   √²≈√∞  4qlo:A00  5

# %%
df_agg = df.groupby(["hit", "N"]).size().reset_index(name="frequency").rename(columns={"N":"length"})

# %%
df_agg.head()
# Out:
#      hit  length  frequency
# 0      !       1      17800
# 1     !!       2       1238
# 2    !!!       3         93
# 3   !!!!       4         11
# 4  !!!!/       5          2

# %%
df_agg_sum = df_agg.groupby("length").apply(lambda x: sum(x.frequency)).reset_index(name="frequency")
df_agg_sum.head(50)
# Out:
#     length  frequency
# 0        1    2408011
# 1        2    4450337
# 2        3    2625268
# 3        4     551391
# 4        5     114596
# 5        6      26605
# 6        7      10261
# 7        8       6277
# 8        9       4332
# 9       10       3104
# 10      11       2299
# 11      12       1720
# 12      13       1322
# 13      14       1007
# 14      15        759
# 15      16        581
# 16      17        429
# 17      18        353
# 18      19        282
# 19      20        223
# 20      21        167
# 21      22        143
# 22      23        121
# 23      24        106
# 24      25         92
# 25      26         74
# 26      27         61
# 27      28         43
# 28      29         35
# 29      30         33
# 30      31         27
# 31      32         27
# 32      33         25
# 33      34         22
# 34      35         22
# 35      36         19
# 36      37         12
# 37      38         10
# 38      39         10
# 39      40         10
# ...

# %%
sns.barplot(df_agg_sum.length, df_agg_bar.frequency)

# %%
sns.boxplot(df_agg.length, df_agg.frequency)

# %%
sns.barplot(df_agg_sum.length, np.log(df_agg_bar.frequency))

# %%
np.median(df_agg[df_agg.length == 2].frequency)
# Out:
# 47.0
